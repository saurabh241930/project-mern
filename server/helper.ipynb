# %%
from pymongo import MongoClient
from datetime import datetime
from bson.objectid import ObjectId
from datetime import date
from datetime import timedelta

URL = "mongodb+srv://chirag773:chirag123@inspactio-6btjg.mongodb.net/cmc?authSource=admin&replicaSet=inspactio-shard-0&w=majority&readPreference=primary&appname=MongoDB%20Compass&retryWrites=true&ssl=true"


client = MongoClient(URL)

# %%
db = client['cmc']
db.collection_names()
# Out:
# <ipython-input-28-d296a135daf2>:2: DeprecationWarning: collection_names is deprecated. Use list_collection_names instead.
#   db.collection_names()
# ['slots', 'users', 'angles', 'marbles2', 'categories', 'marbles']

# %%
now = datetime.now()

marbles = db['marbles']
temp = db['temp']
marble_stock = db['marble_stock']
angles = db['angles']
categories = db['categories']

# %%
for m in list(marbles.find({})):
    found_category = categories.find_one({"qualityName":m['qualityName']})
    marbles.update_one({'_id':m['_id']},
                       {'$set':{
                           'image':found_category['image']
                       }},
                       upsert=True
                      )

# %%
# q = marbles.aggregate([{"$group":{'_id':"$angle", 'count':{'$sum':1}},
#                         {'array':{
#                             '$push':{
#                                 'quality':'$qualityName'
#                             }
#                         }}
#                        }])

# doc = list(q)
# # f = []
# # for d in doc:
# #     l = list(marbles.find({"qualityName":d['_id']}))
# #     for m in l:
# #         print(marbles.find({"qualityName":}))

    
# doc

list(marbles.aggregate([
   {
      "$group": {
         '_id': '$angle',
         'marbles': {
            '$push': {
               'qualityName': '$qualityName',
                'basicMaterial':'$basicMaterial',
                'description':'$description',
                'material':'$material',
                'blockBatchNo':'$blockBatchNo',
                'color':'$color'
            }
         },
         'count':{'$sum':1}
      }
   }
]))
# Out:
# [{'_id': '90',
#   'marbles': [{'qualityName': 'SPIDER BLACK',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'HNMS SPD.BLK_AE-18MM-IMFG',
#     'material': '30035936',
#     'blockBatchNo': 'LJ01919',
#     'color': 'BLACK'},
#    {'qualityName': 'SPIDER BLACK',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS SPD.BLK_AE-18MM-IMFG',
#     'material': '30035951',
#     'blockBatchNo': 'LJ01919',
#     'color': 'BLACK'},
#    {'qualityName': 'SAINT LAURENT',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS SNT.LRNT_TN-18MM-IMFG',
#     'material': '30030202',
#     'blockBatchNo': 'LI01281',
#     'color': 'BROWN'}],
#   'count': 3},
#  {'_id': '88',
#   'marbles': [{'qualityName': 'SAINT LAURENT',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS SNT.LRNT_TR-20MM-IMFG',
#     'material': '30033834',
#     'blockBatchNo': 'LD00542',
#     'color': 'BLACK'},
#    {'qualityName': 'SAINT LAURENT',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS SNT.LRNT_TN-20MM-IMFG',
#     'material': '30030203',
#     'blockBatchNo': 'LI00120',
#     'color': 'BROWN'},
#    {'qualityName': 'SILKER BROWN',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS SLKR.BRN_TR-18MM-IMFG',
#     'material': '30033812',
#     'blockBatchNo': 'LJ01818',
#     'color': 'BROWN'}],
#   'count': 3},
#  {'_id': '35',
#   'marbles': [{'qualityName': 'TOBACCO BROWN',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS TBC.BRN_CA-20MM-IMFG',
#     'material': '30030212',
#     'blockBatchNo': 'LF61939B',
#     'color': 'BROWN'}],
#   'count': 1},
#  {'_id': '115',
#   'marbles': [{'qualityName': 'PETRA BROWN',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS PETRA.BRN_TR-18MM-IMFG',
#     'material': '30030172',
#     'blockBatchNo': 'LI02173',
#     'color': 'BROWN'}],
#   'count': 1},
#  {'_id': '76',
#   'marbles': [{'qualityName': 'BROWN LAZULY',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS BRN.LZLY_IT-18MM-IMFG',
#     'material': '30030016',
#     'blockBatchNo': 'LE01339',
#     'color': 'BROWN'}],
#   'count': 1},
#  {'_id': '39',
#   'marbles': [{'qualityName': 'PEARL ARMANI',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'HNMS PRL.ARMN_TR-18MM-IMFG',
#     'material': '30029866',
#     'blockBatchNo': 'LH61534',
#     'color': 'BROWN'}],
#   'count': 1},
#  {'_id': '21',
#   'marbles': [{'qualityName': 'SILKER BROWN',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'HNMS SLKR.BRN_TR-18MM-IMFG',
#     'material': '30033110',
#     'blockBatchNo': 'LJ01819',
#     'color': 'BROWN'},
#    {'qualityName': 'TERRACOTTA',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'HNMS TERRACOTTA_TR-20MM-IMFG',
#     'material': '30031425',
#     'blockBatchNo': 'LH00661',
#     'color': 'BEIGE'}],
#   'count': 2},
#  {'_id': '3',
#   'marbles': [{'qualityName': 'ARMANI BROWN',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS ARMN.BRN_TR-18MM-IMFG',
#     'material': '30029962',
#     'blockBatchNo': 'LJ01211',
#     'color': 'BROWN'},
#    {'qualityName': 'ARMANI BROWN',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'HNMS ARMN.BRN_TR-18MM-IMFG',
#     'material': '30029542',
#     'blockBatchNo': 'LJ01211',
#     'color': 'BROWN'}],
#   'count': 2},
#  {'_id': '83',
#   'marbles': [{'qualityName': 'TERRACOTTA',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS TERRACOTTA_TR-18MM-IMFG',
#     'material': '30031427',
#     'blockBatchNo': 'LJ00763',
#     'color': 'BEIGE'}],
#   'count': 1},
#  {'_id': '99',
#   'marbles': [{'qualityName': 'SAINT LAURENT',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'HNMS SNT.LRNT_TR-18MM-IMFG',
#     'material': '30033131',
#     'blockBatchNo': 'LF00353',
#     'color': 'BLACK'},
#    {'qualityName': 'SAINT LAURENT',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS SNT.LRNT_TR-18MM-IMFG',
#     'material': '30033833',
#     'blockBatchNo': 'LF00353',
#     'color': 'BLACK'}],
#   'count': 2},
#  {'_id': '110',
#   'marbles': [{'qualityName': 'GRIGIO VENATO',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS GRG.VENTO_GR-16MM-IMP',
#     'material': '40001257',
#     'blockBatchNo': '10K/1065',
#     'color': 'BEIGE'}],
#   'count': 1},
#  {'_id': '62',
#   'marbles': [{'qualityName': 'BLACK WAVE',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'HNMS BLK.WAVE_CN-18MM-IMFG',
#     'material': '30029608',
#     'blockBatchNo': 'LI01366',
#     'color': 'BLACK'}],
#   'count': 1},
#  {'_id': '70',
#   'marbles': [{'qualityName': 'EMPERADOR',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS EMPERADOR_TR-16MM-IMFG',
#     'material': '30034816',
#     'blockBatchNo': 'LJ01110',
#     'color': 'BROWN'},
#    {'qualityName': 'DARK EMPRADOR',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'HNMS DARK.EMP_TR-18MM-IMFG',
#     'material': '30029623',
#     'blockBatchNo': 'LG60999',
#     'color': 'BROWN'},
#    {'qualityName': 'DARK EMPRADOR',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS DARK.EMP_TR-18MM-IMFG',
#     'material': '30030043',
#     'blockBatchNo': 'LG60999',
#     'color': 'BROWN'}],
#   'count': 3},
#  {'_id': '40',
#   'marbles': [{'qualityName': 'ROSATIKA',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS ROSATIKA_TR-16MM-IMFG',
#     'material': '30030183',
#     'blockBatchNo': 'LH00221',
#     'color': 'BROWN'}],
#   'count': 1},
#  {'_id': '112',
#   'marbles': [{'qualityName': 'IRISH BROWN',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS IRIS.BRN_CN-16MM-IMFG',
#     'material': '30031018',
#     'blockBatchNo': 'LJ00655',
#     'color': 'BROWN'},
#    {'qualityName': 'IRISH BROWN',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'HNMS IRIS.BRN_CN-16MM-IMFG',
#     'material': '30031017',
#     'blockBatchNo': 'LJ00655',
#     'color': 'BROWN'}],
#   'count': 2},
#  {'_id': '44',
#   'marbles': [{'qualityName': 'ROSSO CASATA',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'HNMS RS.CASATA_CS-18MM-IMFG',
#     'material': '30030780',
#     'blockBatchNo': 'LJ00693',
#     'color': 'BROWN'}],
#   'count': 1},
#  {'_id': '65',
#   'marbles': [{'qualityName': 'SAINT LAURENT',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'HNMS SNT.LRNT_TN-18MM-IMFG',
#     'material': '30029782',
#     'blockBatchNo': 'LJ01027',
#     'color': 'BROWN'}],
#   'count': 1},
#  {'_id': '68',
#   'marbles': [{'qualityName': 'VENICE BROWN',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS VNC.BRN_CN-18MM-IMP',
#     'material': '40001050',
#     'blockBatchNo': '11KJ064',
#     'color': 'BROWN'}],
#   'count': 1},
#  {'_id': '81',
#   'marbles': [{'qualityName': 'BEIGE BENZ BROWN',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS BGE.BNZ.BRN_AL-18MM-IMFG',
#     'material': '30031171',
#     'blockBatchNo': 'LJ00594',
#     'color': 'BROWN'},
#    {'qualityName': 'BEIGE BENZ BROWN',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'HNMS BGE.BNZ.BRN_AL-18MM-IMFG',
#     'material': '30031168',
#     'blockBatchNo': 'LJ00594',
#     'color': 'BROWN'},
#    {'qualityName': 'SAINT LAURENT',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'HNMS SNT.LRNT_TN-20MM-IMFG',
#     'material': '30029783',
#     'blockBatchNo': 'LI00115',
#     'color': 'BROWN'}],
#   'count': 3},
#  {'_id': '72',
#   'marbles': [{'qualityName': 'GOLDEN PORTORO',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS GLD.PORTO_DO-20MM-IMFG',
#     'material': '30030086',
#     'blockBatchNo': 'LE60272',
#     'color': 'BLACK'},
#    {'qualityName': 'GOLDEN PORTORO',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'HNMS GLD.PORTO_DO-20MM-IMFG',
#     'material': '30029666',
#     'blockBatchNo': 'LE60272',
#     'color': 'BLACK'}],
#   'count': 2},
#  {'_id': '118',
#   'marbles': [{'qualityName': 'ROSATIKA',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'HNMS ROSATIKA_TR-18MM-IMFG',
#     'material': '30029764',
#     'blockBatchNo': 'LG60831',
#     'color': 'BROWN'},
#    {'qualityName': 'ROSATIKA',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS ROSATIKA_TR-18MM-IMFG',
#     'material': '30030184',
#     'blockBatchNo': 'LG60831',
#     'color': 'BROWN'}],
#   'count': 2},
#  {'_id': '71',
#   'marbles': [{'qualityName': 'BROWN FANTACY DIANA',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS BRN.FNTS.DNA_CN-18MM-IMP',
#     'material': '40001345',
#     'blockBatchNo': '11KI105',
#     'color': 'BROWN'},
#    {'qualityName': 'EMPRADAR LIGHT',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'HNMS EMP.LT_TR-18MM-IMFG',
#     'material': '30029857',
#     'blockBatchNo': 'LI00276',
#     'color': 'BROWN'}],
#   'count': 2},
#  {'_id': '66',
#   'marbles': [{'qualityName': 'EMPERADOR',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'HNMS EMPERADOR_TR-16MM-IMFG',
#     'material': '30034813',
#     'blockBatchNo': 'LJ01111',
#     'color': 'BROWN'}],
#   'count': 1},
#  {'_id': '31',
#   'marbles': [{'qualityName': 'MONACO BROWN',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'HNMS MNC.BRN_TR-18MM-IMFG',
#     'material': '30029725',
#     'blockBatchNo': 'LH61076',
#     'color': 'BROWN'}],
#   'count': 1},
#  {'_id': '58',
#   'marbles': [{'qualityName': 'BLACK MARQUINA',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'HNMS BLK.MRQ_MA-16MM-IMFG',
#     'material': '30029577',
#     'blockBatchNo': 'LI02516',
#     'color': 'BLACK'},
#    {'qualityName': 'BLACK MARQUINA',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS BLK.MRQ_MA-16MM-IMFG',
#     'material': '30029997',
#     'blockBatchNo': 'LI02516',
#     'color': 'BLACK'},
#    {'qualityName': 'TOBACCO BROWN',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'HNMS TBC.BRN_CA-20MM-IMFG',
#     'material': '30029792',
#     'blockBatchNo': 'LF62916A',
#     'color': 'BROWN'}],
#   'count': 3},
#  {'_id': '11',
#   'marbles': [{'qualityName': 'ARMANI BROWN',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'HNMS ARMN.BRN_TR-16MM-IMFG',
#     'material': '30029541',
#     'blockBatchNo': 'LJ01212',
#     'color': 'BROWN'}],
#   'count': 1},
#  {'_id': '6',
#   'marbles': [{'qualityName': 'ARMANI BROWN',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS ARMN.BRN_TR-16MM-IMFG',
#     'material': '30029961',
#     'blockBatchNo': 'LJ00614',
#     'color': 'BROWN'}],
#   'count': 1},
#  {'_id': '95',
#   'marbles': [{'qualityName': 'IRISH BROWN',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS IRIS.BRN_CN-18MM-IMFG',
#     'material': '30031025',
#     'blockBatchNo': 'LJ00685',
#     'color': 'BROWN'},
#    {'qualityName': 'IRISH BROWN',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'HNMS IRIS.BRN_CN-18MM-IMFG',
#     'material': '30031023',
#     'blockBatchNo': 'LJ00685',
#     'color': 'BROWN'}],
#   'count': 2},
#  {'_id': '2',
#   'marbles': [{'qualityName': 'AMARONE BROWN',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'HNMS AMRON.BRN_AE-18MM-IMFG',
#     'material': '30029914',
#     'blockBatchNo': 'LI02587',
#     'color': 'BROWN'},
#    {'qualityName': 'AMARONE BROWN',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS AMRON.BRN_AE-18MM-IMFG',
#     'material': '30030334',
#     'blockBatchNo': 'LI02587',
#     'color': 'BROWN'}],
#   'count': 2},
#  {'_id': '57',
#   'marbles': [{'qualityName': 'CELSIUM BLACK',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS CLSM.BLK_CN-20MM-IMP',
#     'material': '40001373',
#     'blockBatchNo': 'K00CB50',
#     'color': 'BLACK'},
#    {'qualityName': 'TOBACCO BROWN CROSS CUT',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS TBC.BRNCRC_IT-20MM-IMP',
#     'material': '40001605',
#     'blockBatchNo': 'K00TB23',
#     'color': 'BROWN'}],
#   'count': 2},
#  {'_id': '87',
#   'marbles': [{'qualityName': 'BLACK ARMANI',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'HNMS BLK.ARMN_IR-20MM-IMFG',
#     'material': '30029567',
#     'blockBatchNo': 'LI00937',
#     'color': 'BLACK'},
#    {'qualityName': 'BLACK ARMANI',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS BLK.ARMN_IR-20MM-IMFG',
#     'material': '30029987',
#     'blockBatchNo': 'LI00937',
#     'color': 'BLACK'}],
#   'count': 2},
#  {'_id': '61',
#   'marbles': [{'qualityName': 'GOLDEN PORTORO',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS GLD.PORTO_DO-16MM-IMP',
#     'material': '40001256',
#     'blockBatchNo': '21KH0231',
#     'color': 'BLACK'},
#    {'qualityName': 'GOLDEN PORTORO',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS GLD.PORTO_CN-20MM-IMP',
#     'material': '40001183',
#     'blockBatchNo': '21KG0178',
#     'color': 'BLACK'},
#    {'qualityName': 'BLACK MARQUINA',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS BLK.MRQ_CN-18MM-IMP',
#     'material': '40001072',
#     'blockBatchNo': '11KI005',
#     'color': 'BLACK'},
#    {'qualityName': 'GOLDEN PORTORO',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS GLD.PORTO_CN-18MM-IMP',
#     'material': '40001123',
#     'blockBatchNo': '21UF0072',
#     'color': 'BLACK'}],
#   'count': 4},
#  {'_id': '10',
#   'marbles': [{'qualityName': 'ROSATIKA',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'HNMS ROSATIKA_TR-16MM-IMFG',
#     'material': '30029763',
#     'blockBatchNo': 'LH00220',
#     'color': 'BROWN'}],
#   'count': 1},
#  {'_id': '59',
#   'marbles': [{'qualityName': 'IRISH BROWN',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS IRIS.BRN_CN-16MM-IMP',
#     'material': '40001128',
#     'blockBatchNo': '21KH0265',
#     'color': 'BROWN'},
#    {'qualityName': 'BROWN PERLA',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS BRN.PERLA_TR-18MM-IMFG',
#     'material': '30030660',
#     'blockBatchNo': 'LG60756',
#     'color': 'BROWN'},
#    {'qualityName': 'BROWN PERLA',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'HNMS BRN.PERLA_TR-18MM-IMFG',
#     'material': '30030603',
#     'blockBatchNo': 'LG60756',
#     'color': 'BROWN'}],
#   'count': 3},
#  {'_id': '7',
#   'marbles': [{'qualityName': 'PEARL ARMANI BROWN',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS PRL.ARM.BRN_TR-18MM-IMFG',
#     'material': '30033734',
#     'blockBatchNo': 'LH61066',
#     'color': 'BROWN'}],
#   'count': 1},
#  {'_id': '69',
#   'marbles': [{'qualityName': 'BROWN LAZULY',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'HNMS BRN.LZLY_IT-18MM-IMFG',
#     'material': '30029596',
#     'blockBatchNo': 'LF62236',
#     'color': 'BROWN'}],
#   'count': 1},
#  {'_id': '121',
#   'marbles': [{'qualityName': 'RTM BEIGE',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'HNMS RTM.BGE_TR-18MM-IMFG',
#     'material': '30031480',
#     'blockBatchNo': 'LJ00784',
#     'color': 'BEIGE'},
#    {'qualityName': 'RTM BEIGE',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS RTM.BGE_TR-18MM-IMFG',
#     'material': '30031489',
#     'blockBatchNo': 'LJ00784',
#     'color': 'BEIGE'}],
#   'count': 2},
#  {'_id': '106',
#   'marbles': [{'qualityName': 'CLASSIC PICASO',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'HNMS CLS.PICASO_TR-20MM-IMFG',
#     'material': '30032708',
#     'blockBatchNo': 'LG61001',
#     'color': 'BLACK'},
#    {'qualityName': 'CLASSIC PICASO',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'ONMS CLS.PICASO_TR-20MM-IMFG',
#     'material': '30034113',
#     'blockBatchNo': 'LG61001',
#     'color': 'BLACK'},
#    {'qualityName': 'CLASSIC PICASO',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS CLS.PICASO_TR-20MM-IMFG',
#     'material': '30033411',
#     'blockBatchNo': 'LG61001',
#     'color': 'BLACK'}],
#   'count': 3},
#  {'_id': '75',
#   'marbles': [{'qualityName': 'DARK EMPRADOR',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS DARK.EMP_TR-20MM-IMFG',
#     'material': '30030044',
#     'blockBatchNo': 'LH61680',
#     'color': 'BROWN'}],
#   'count': 1},
#  {'_id': '104',
#   'marbles': [{'qualityName': 'FANTASY BROWN',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'HNMS FNTSY.BRN_TR-18MM-IMFG',
#     'material': '30030633',
#     'blockBatchNo': 'LJ00214',
#     'color': 'BROWN'},
#    {'qualityName': 'FANTASY BROWN',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS FNTSY.BRN_TR-18MM-IMFG',
#     'material': '30030690',
#     'blockBatchNo': 'LJ00214',
#     'color': 'BROWN'}],
#   'count': 2},
#  {'_id': '125',
#   'marbles': [{'qualityName': 'PEARL ARMANI BROWN',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'HNMS PRL.ARM.BRN_TR-18MM-IMFG',
#     'material': '30033032',
#     'blockBatchNo': 'LH61068',
#     'color': 'BROWN'}],
#   'count': 1},
#  {'_id': '94',
#   'marbles': [{'qualityName': 'BRECCIA BROWN',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS BRC.BRN_TR-18MM-IMFG',
#     'material': '30030672',
#     'blockBatchNo': 'LJ01931',
#     'color': 'BROWN'}],
#   'count': 1},
#  {'_id': '27',
#   'marbles': [{'qualityName': 'BRECCIA ONICIATA',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS BC.ONC_IT-18MM-IMFG',
#     'material': '30029929',
#     'blockBatchNo': 'LI02577',
#     'color': 'BEIGE'},
#    {'qualityName': 'BRECCIA ONICIATA',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'HNMS BC.ONC_IT-18MM-IMFG',
#     'material': '30029509',
#     'blockBatchNo': 'LI02577',
#     'color': 'BEIGE'},
#    {'qualityName': 'PETRA BROWN',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'HNMS PETRA.BRN_TR-18MM-IMFG',
#     'material': '30029752',
#     'blockBatchNo': 'LI02172',
#     'color': 'BROWN'}],
#   'count': 3},
#  {'_id': '126',
#   'marbles': [{'qualityName': 'MONACO BROWN',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS MNC.BRN_TR-18MM-IMFG',
#     'material': '30030145',
#     'blockBatchNo': 'LH61652',
#     'color': 'BROWN'}],
#   'count': 1},
#  {'_id': '36',
#   'marbles': [{'qualityName': 'TERRACOTTA',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS TERRACOTTA_TR-20MM-IMFG',
#     'material': '30031428',
#     'blockBatchNo': 'LH00659',
#     'color': 'BEIGE'}],
#   'count': 1},
#  {'_id': '51',
#   'marbles': [{'qualityName': 'WHITE PORTORO',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS WHT.PORTRO_CN-20MM-IMP',
#     'material': '40001642',
#     'blockBatchNo': '11KI176',
#     'color': 'BLACK'}],
#   'count': 1},
#  {'_id': '49',
#   'marbles': [{'qualityName': 'ROSSO CASATA',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS RS.CASATA_CS-18MM-IMFG',
#     'material': '30030783',
#     'blockBatchNo': 'LJ00689',
#     'color': 'BROWN'}],
#   'count': 1},
#  {'_id': '45',
#   'marbles': [{'qualityName': 'ROSSO CASATA',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'ONMS RS.CASATA_CS-18MM-IMFG',
#     'material': '30031545',
#     'blockBatchNo': 'LJ00691',
#     'color': 'BROWN'}],
#   'count': 1},
#  {'_id': '89',
#   'marbles': [{'qualityName': 'TERRACOTTA',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'HNMS TERRACOTTA_TR-18MM-IMFG',
#     'material': '30031424',
#     'blockBatchNo': 'LJ00764',
#     'color': 'BEIGE'}],
#   'count': 1},
#  {'_id': '74',
#   'marbles': [{'qualityName': 'BLACK MARQUINA',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS BLK.MRQ_CN-20MM-IMP',
#     'material': '40001226',
#     'blockBatchNo': '11KJ217',
#     'color': 'BLACK'}],
#   'count': 1},
#  {'_id': '60',
#   'marbles': [{'qualityName': 'GRIGIO VENATO',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS GRG.VENTO_GR-20MM-IMFG',
#     'material': '30030269',
#     'blockBatchNo': 'LG60933',
#     'color': 'BEIGE'}],
#   'count': 1},
#  {'_id': '63',
#   'marbles': [{'qualityName': 'BLACK MARQUINA',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'ONMS BLK.MRQ_MA-18MM-IMFG',
#     'material': '30036427',
#     'blockBatchNo': 'LH61607',
#     'color': 'BLACK'},
#    {'qualityName': 'BLACK MARQUINA',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS BLK.MRQ_MA-18MM-IMFG',
#     'material': '30029998',
#     'blockBatchNo': 'LG61270',
#     'color': 'BLACK'},
#    {'qualityName': 'BLACK MARQUINA',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'HNMS BLK.MRQ_MA-18MM-IMFG',
#     'material': '30029578',
#     'blockBatchNo': 'LH61607',
#     'color': 'BLACK'}],
#   'count': 3},
#  {'_id': '17',
#   'marbles': [{'qualityName': 'OCEAN BROWN',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS OCN.BRN_TR-18MM-IMFG',
#     'material': '30030642',
#     'blockBatchNo': 'LJ00064',
#     'color': 'BROWN'},
#    {'qualityName': 'OCEAN BROWN',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'HNMS OCN.BRN_TR-18MM-IMFG',
#     'material': '30030585',
#     'blockBatchNo': 'LJ00064',
#     'color': 'BROWN'}],
#   'count': 2},
#  {'_id': '67',
#   'marbles': [{'qualityName': 'GOLDEN PORTORO',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'RNMS GLD.PORTO_CN-18MM-IMP',
#     'material': '40001772',
#     'blockBatchNo': '11KJ244',
#     'color': 'BLACK'},
#    {'qualityName': 'BLACK MARQUINA',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS BLK.MRQ_IN-20MM-IND',
#     'material': '40001748',
#     'blockBatchNo': '11KJ215',
#     'color': 'BLACK'}],
#   'count': 2},
#  {'_id': '107',
#   'marbles': [{'qualityName': 'BIJOU.BRN',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'HNMS BIJOU.BRN_TR-18MM-IMFG',
#     'material': '30035047',
#     'blockBatchNo': 'LJ01067',
#     'color': 'BROWN'},
#    {'qualityName': 'BIJOU.BRN',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS BIJOU.BRN_TR-18MM-IMFG',
#     'material': '30035059',
#     'blockBatchNo': 'LJ01067',
#     'color': 'BROWN'}],
#   'count': 2},
#  {'_id': '37',
#   'marbles': [{'qualityName': 'BROWN ONYX',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'HNMS BRN.ONYX_PK-20MM-IMFG',
#     'material': '30032654',
#     'blockBatchNo': 'LE60441B',
#     'color': 'BROWN'},
#    {'qualityName': 'BROWN ONYX',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'PNMS BRN.ONYX_PK-20MM-IMFG',
#     'material': '30033357',
#     'blockBatchNo': 'LE60441B',
#     'color': 'BROWN'}],
#   'count': 2},
#  {'_id': '79',
#   'marbles': [{'qualityName': 'BRECCIA BROWN',
#     'basicMaterial': 'NATURAL MARBLE SLABS',
#     'description': 'HNMS BRC.BRN_TR-18MM-IMFG',
#     'material': '30030615',
#     'blockBatchNo': 'LJ01934',
#     'color': 'BROWN'}],
#   'count': 1}]

# %%
import random


images = ['https://5.imimg.com/data5/NE/VV/PE/SELLER-4851368/kajaria-1200-x-1200-mm-dyna-pearl-marble-500x500.jpg',
          'https://www.bhutrastones.com/wp-content/uploads/2018/11/Beige.jpg',
          'https://4.imimg.com/data4/LW/DQ/MY-10354786/artificial-quartz-500x500.jpg',
          'https://www.bhutrastones.com/wp-content/uploads/2018/12/Statuarietto-1024x683-Copy-1.jpg']

for d in doc:
    o = {
        'qualityName':d['_id'],
        'quantity':d['count'],
        'colors':marbles.find({"qualityName":d["_id"]}).distinct("color"),
        'basicMaterial':marbles.find({"qualityName":d["_id"]}).distinct("basicMaterial")[0],
        'marbles':marbles.find({"qualityName":d["_id"]}).distinct("_id"),
        'image':random.choice(images)
    }
    categories.insert_one(o)

# %%
angles.remove({})
# Out:
# <ipython-input-64-e6840c2d1c79>:1: DeprecationWarning: remove is deprecated. Use delete_one or delete_many instead.
#   angles.remove({})
# {'n': 38,
#  'opTime': {'ts': Timestamp(1635413907, 38), 't': 158},
#  'electionId': ObjectId('7fffffff000000000000009e'),
#  'ok': 1.0,
#  '$clusterTime': {'clusterTime': Timestamp(1635413907, 38),
#   'signature': {'hash': b'>whn\xc1\xb8\xcav\xc1\xdfj\xb6i\xa4\x85\\$\x15-\xe8',
#    'keyId': 6972098799044919298}},
#  'operationTime': Timestamp(1635413907, 38)}

# %%
for m in list(marbles.find({})):
    marbles.insert_one({
        'color':m['Colour'],
        'basicMaterial':m['Basic Material'],
        'qualityName':m['Mara-Quality Name'],
        'storageLocation':m['Storage location'],
        'angle':m['Hanger and Angle'],
        'blockBatchNo':m['Block Batch Number'],
        'material':m['Material'],
        'description':m['Material description']
    })
    
#     marbles.insert_one({
#         'Colour':m['color'],
#         'Basic Material':m['basicMaterial'],
#         'Mara-Quality Name':m['qualityName'],
#         'Storage location':m['storageLocation'],
#         'Hanger and Angle':m['angle'],
#         'Block Batch Number':m['blockBatchNo'],
#         'Material':m['material'],
#         'Material description':m['description']
#     })
    
#     marbles.remove({"_id":m['_id']})

# %%
list(marbles.find({"storageLocation":"1131"}).distinct('angle'))
# Out:
# ['10',
#  '106',
#  '107',
#  '17',
#  '31',
#  '51',
#  '58',
#  '59',
#  '61',
#  '62',
#  '63',
#  '65',
#  '67',
#  '72',
#  '74',
#  '81',
#  '87',
#  '88',
#  '90']

# %%
for m in list(marbles.find({})):
    dups = list(marbles.find({'description':m['description']}))
    dup_to_remove = dups[1:]
    for d in dup_to_remove:
        marbles.remove({'_id':m['_id']})
# Out:
# <ipython-input-25-114015f35193>:5: DeprecationWarning: remove is deprecated. Use delete_one or delete_many instead.
#   marbles.remove({'_id':m['_id']})
