# %%
from pymongo import MongoClient
from datetime import datetime
from bson.objectid import ObjectId
from datetime import date
from datetime import timedelta

URL = "mongodb+srv://chirag773:chirag123@inspactio-6btjg.mongodb.net/cmc?authSource=admin&replicaSet=inspactio-shard-0&w=majority&readPreference=primary&appname=MongoDB%20Compass&retryWrites=true&ssl=true"


client = MongoClient(URL)

# %%
db = client['cmc']
db.collection_names()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: DeprecationWarning: collection_names is deprecated. Use list_collection_names instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# ['slots', 'marbles2', 'users', 'angles', 'marbles']

# %%
now = datetime.now()

marbles = db['marbles']


list(marbles.find({}))
# Out:
# [{'_id': ObjectId('5fec3ccbf0f1441818b0c56e'),
#   'Colour': 'BEIGE',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'RTM BEIGE',
#   'Storage location': '1130',
#   'Hanger and Angle': '121',
#   'Block Batch Number': 'LJ00784',
#   'Material': '30031480',
#   'Material description': 'HNMS RTM.BGE_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3ccef0f1441818b0c574'),
#   'Colour': 'BEIGE',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'TERRACOTTA',
#   'Storage location': '1130',
#   'Hanger and Angle': '36',
#   'Block Batch Number': 'LH00659',
#   'Material': '30031425',
#   'Material description': 'HNMS TERRACOTTA_TR-20MM-IMFG'},
#  {'_id': ObjectId('5fec3cd0f0f1441818b0c57e'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BLACK MARQUINA',
#   'Storage location': '1131',
#   'Hanger and Angle': '58',
#   'Block Batch Number': 'LH61611',
#   'Material': '30029577',
#   'Material description': 'HNMS BLK.MRQ_MA-16MM-IMFG'},
#  {'_id': ObjectId('5fec3cd0f0f1441818b0c578'),
#   'Colour': 'BEIGE',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'TERRACOTTA',
#   'Storage location': '1130',
#   'Hanger and Angle': '21',
#   'Block Batch Number': 'LH00661',
#   'Material': '30031428',
#   'Material description': 'PNMS TERRACOTTA_TR-20MM-IMFG'},
#  {'_id': ObjectId('5fec3cd0f0f1441818b0c57c'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BLACK ARMANI',
#   'Storage location': '1130',
#   'Hanger and Angle': '9',
#   'Block Batch Number': 'LH00953',
#   'Material': '30029987',
#   'Material description': 'PNMS BLK.ARMN_IR-20MM-IMFG'},
#  {'_id': ObjectId('5fec3cd0f0f1441818b0c582'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BLACK MARQUINA',
#   'Storage location': '1131',
#   'Hanger and Angle': '70',
#   'Block Batch Number': 'LH61612',
#   'Material': '30029578',
#   'Material description': 'HNMS BLK.MRQ_MA-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cd0f0f1441818b0c586'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BLACK MARQUINA',
#   'Storage location': '1131',
#   'Hanger and Angle': '63',
#   'Block Batch Number': 'LH61607',
#   'Material': '30029998',
#   'Material description': 'PNMS BLK.MRQ_MA-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cd1f0f1441818b0c58d'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BLACK MARQUINA',
#   'Storage location': '1131',
#   'Hanger and Angle': '61',
#   'Block Batch Number': '21KH0229',
#   'Material': '40001072',
#   'Material description': 'PNMS BLK.MRQ_CN-18MM-IMP'},
#  {'_id': ObjectId('5fec3cd1f0f1441818b0c59b'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'CLASSIC PICASO',
#   'Storage location': '1131',
#   'Hanger and Angle': '106',
#   'Block Batch Number': 'LG61001',
#   'Material': '30032708',
#   'Material description': 'HNMS CLS.PICASO_TR-20MM-IMFG'},
#  {'_id': ObjectId('5fec3cd3f0f1441818b0c59e'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'GOLDEN PORTORO',
#   'Storage location': '1131',
#   'Hanger and Angle': '71',
#   'Block Batch Number': 'LE60271',
#   'Material': '30029666',
#   'Material description': 'HNMS GLD.PORTO_DO-20MM-IMFG'},
#  {'_id': ObjectId('5fec3cd4f0f1441818b0c5ab'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'GOLDEN PORTORO',
#   'Storage location': '1131',
#   'Hanger and Angle': '61',
#   'Block Batch Number': '21KH0231',
#   'Material': '40001256',
#   'Material description': 'PNMS GLD.PORTO_DO-16MM-IMP'},
#  {'_id': ObjectId('5fec3cd4f0f1441818b0c5b1'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'SPIDER BLACK',
#   'Storage location': '1130',
#   'Hanger and Angle': '87',
#   'Block Batch Number': 'LJ01922',
#   'Material': '30035936',
#   'Material description': 'HNMS SPD.BLK_AE-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cd5f0f1441818b0c5bd'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'ARMANI BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '24',
#   'Block Batch Number': 'LH00447',
#   'Material': '30029541',
#   'Material description': 'HNMS ARMN.BRN_TR-16MM-IMFG'},
#  {'_id': ObjectId('5fec3cd5f0f1441818b0c5bf'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'ARMANI BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '6',
#   'Block Batch Number': 'LJ00614',
#   'Material': '30029541',
#   'Material description': 'HNMS ARMN.BRN_TR-16MM-IMFG'},
#  {'_id': ObjectId('5fec3cd5f0f1441818b0c5c2'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'ARMANI BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '10',
#   'Block Batch Number': 'LI00842',
#   'Material': '30029961',
#   'Material description': 'PNMS ARMN.BRN_TR-16MM-IMFG'},
#  {'_id': ObjectId('5fec3cd6f0f1441818b0c5cf'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BIJOU.BRN',
#   'Storage location': '1131',
#   'Hanger and Angle': '107',
#   'Block Batch Number': 'LJ01067',
#   'Material': '30035047',
#   'Material description': 'HNMS BIJOU.BRN_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cdaf0f1441818b0c5ee'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'DARK EMPRADOR',
#   'Storage location': '1130',
#   'Hanger and Angle': '74',
#   'Block Batch Number': 'LH61686',
#   'Material': '30030043',
#   'Material description': 'PNMS DARK.EMP_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cdbf0f1441818b0c5f5'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'FANTASY BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '101',
#   'Block Batch Number': 'LJ00215',
#   'Material': '30030633',
#   'Material description': 'HNMS FNTSY.BRN_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cdef0f1441818b0c615'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'PEARL ARMANI BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '24',
#   'Block Batch Number': 'LH61061',
#   'Material': '30033032',
#   'Material description': 'HNMS PRL.ARM.BRN_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cdef0f1441818b0c61a'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'PETRA BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '115',
#   'Block Batch Number': 'LI02173',
#   'Material': '30029752',
#   'Material description': 'HNMS PETRA.BRN_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cdff0f1441818b0c627'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'ROSSO CASATA',
#   'Storage location': '1130',
#   'Hanger and Angle': '44',
#   'Block Batch Number': 'LJ00690',
#   'Material': '30030780',
#   'Material description': 'HNMS RS.CASATA_CS-18MM-IMFG'},
#  {'_id': ObjectId('5fec3ce1f0f1441818b0c62c'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'ROSSO CASATA',
#   'Storage location': '1130',
#   'Hanger and Angle': '78',
#   'Block Batch Number': 'LJ00324',
#   'Material': '30030780',
#   'Material description': 'HNMS RS.CASATA_CS-18MM-IMFG'},
#  {'_id': ObjectId('5fec3ce1f0f1441818b0c62e'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'ROSSO CASATA',
#   'Storage location': '1130',
#   'Hanger and Angle': '44',
#   'Block Batch Number': 'LJ00690',
#   'Material': '30030783',
#   'Material description': 'PNMS RS.CASATA_CS-18MM-IMFG'},
#  {'_id': ObjectId('5fec3ce4f0f1441818b0c63d'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'SAINT LAURENT',
#   'Storage location': '1131',
#   'Hanger and Angle': '70',
#   'Block Batch Number': 'LJ00155',
#   'Material': '30029782',
#   'Material description': 'HNMS SNT.LRNT_TN-18MM-IMFG'},
#  {'_id': ObjectId('5fec3ce8f0f1441818b0c64a'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'SAINT LAURENT',
#   'Storage location': '1131',
#   'Hanger and Angle': '59',
#   'Block Batch Number': 'LJ00156',
#   'Material': '30030202',
#   'Material description': 'PNMS SNT.LRNT_TN-18MM-IMFG'},
#  {'_id': ObjectId('5fec3ce8f0f1441818b0c64b'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'SAINT LAURENT',
#   'Storage location': '1131',
#   'Hanger and Angle': '64',
#   'Block Batch Number': 'LJ01031',
#   'Material': '30030202',
#   'Material description': 'PNMS SNT.LRNT_TN-18MM-IMFG'},
#  {'_id': ObjectId('5fec3ce8f0f1441818b0c64c'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'SAINT LAURENT',
#   'Storage location': '1131',
#   'Hanger and Angle': '65',
#   'Block Batch Number': 'LJ01027',
#   'Material': '30030202',
#   'Material description': 'PNMS SNT.LRNT_TN-18MM-IMFG'},
#  {'_id': ObjectId('5fec3ce8f0f1441818b0c64d'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'SAINT LAURENT',
#   'Storage location': '1131',
#   'Hanger and Angle': '68',
#   'Block Batch Number': 'LJ01029',
#   'Material': '30030202',
#   'Material description': 'PNMS SNT.LRNT_TN-18MM-IMFG'},
#  {'_id': ObjectId('5fec3ce8f0f1441818b0c64e'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'SAINT LAURENT',
#   'Storage location': '1131',
#   'Hanger and Angle': '70',
#   'Block Batch Number': 'LJ00155',
#   'Material': '30030202',
#   'Material description': 'PNMS SNT.LRNT_TN-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cecf0f1441818b0c665'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'TOBACCO BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '58',
#   'Block Batch Number': 'LF62916A',
#   'Material': '30030212',
#   'Material description': 'PNMS TBC.BRN_CA-20MM-IMFG'},
#  {'_id': ObjectId('5fec3cd0f0f1441818b0c57f'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BLACK MARQUINA',
#   'Storage location': '1131',
#   'Hanger and Angle': '58',
#   'Block Batch Number': 'LI02516',
#   'Material': '30029577',
#   'Material description': 'HNMS BLK.MRQ_MA-16MM-IMFG'},
#  {'_id': ObjectId('5fec3cd0f0f1441818b0c587'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BLACK MARQUINA',
#   'Storage location': '1131',
#   'Hanger and Angle': '63',
#   'Block Batch Number': 'LH61607',
#   'Material': '30036427',
#   'Material description': 'ONMS BLK.MRQ_MA-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cd1f0f1441818b0c58b'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BLACK MARQUINA',
#   'Storage location': '1131',
#   'Hanger and Angle': '57',
#   'Block Batch Number': '11KJ247',
#   'Material': '40001072',
#   'Material description': 'PNMS BLK.MRQ_CN-18MM-IMP'},
#  {'_id': ObjectId('5fec3cd5f0f1441818b0c5be'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'ARMANI BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '3',
#   'Block Batch Number': 'LJ01216',
#   'Material': '30029541',
#   'Material description': 'HNMS ARMN.BRN_TR-16MM-IMFG'},
#  {'_id': ObjectId('5fec3cd6f0f1441818b0c5cd'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BEIGE BENZ BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '33',
#   'Block Batch Number': 'LJ00600',
#   'Material': '30031171',
#   'Material description': 'PNMS BGE.BNZ.BRN_AL-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cd6f0f1441818b0c5d1'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BRECCIA BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '39',
#   'Block Batch Number': 'LJ00148',
#   'Material': '30030615',
#   'Material description': 'HNMS BRC.BRN_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cd6f0f1441818b0c5d2'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BRECCIA BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '77',
#   'Block Batch Number': 'LJ00146',
#   'Material': '30030615',
#   'Material description': 'HNMS BRC.BRN_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cd6f0f1441818b0c5d5'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BRECCIA BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '39',
#   'Block Batch Number': 'LJ00148',
#   'Material': '30030672',
#   'Material description': 'PNMS BRC.BRN_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cdaf0f1441818b0c5ef'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'DARK EMPRADOR',
#   'Storage location': '1130',
#   'Hanger and Angle': '75',
#   'Block Batch Number': 'LH61680',
#   'Material': '30030044',
#   'Material description': 'PNMS DARK.EMP_TR-20MM-IMFG'},
#  {'_id': ObjectId('5fec3cdcf0f1441818b0c5f8'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'IRISH BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '105',
#   'Block Batch Number': 'LJ00652',
#   'Material': '30031017',
#   'Material description': 'HNMS IRIS.BRN_CN-16MM-IMFG'},
#  {'_id': ObjectId('5fec3cdcf0f1441818b0c600'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'IRISH BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '84',
#   'Block Batch Number': 'LJ00686',
#   'Material': '30031018',
#   'Material description': 'PNMS IRIS.BRN_CN-16MM-IMFG'},
#  {'_id': ObjectId('5fec3cdcf0f1441818b0c603'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'IRISH BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '95',
#   'Block Batch Number': 'LJ00685',
#   'Material': '30031025',
#   'Material description': 'PNMS IRIS.BRN_CN-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cdcf0f1441818b0c605'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'MONACO BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '119',
#   'Block Batch Number': 'LH61077',
#   'Material': '30029725',
#   'Material description': 'HNMS MNC.BRN_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cddf0f1441818b0c607'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'MONACO BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '126',
#   'Block Batch Number': 'LH61652',
#   'Material': '30029725',
#   'Material description': 'HNMS MNC.BRN_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cddf0f1441818b0c612'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'PEARL ARMANI',
#   'Storage location': '1130',
#   'Hanger and Angle': '39',
#   'Block Batch Number': 'LH61534',
#   'Material': '30029866',
#   'Material description': 'HNMS PRL.ARMN_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cdef0f1441818b0c616'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'PEARL ARMANI BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '7',
#   'Block Batch Number': 'LH61066',
#   'Material': '30033032',
#   'Material description': 'HNMS PRL.ARM.BRN_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cdef0f1441818b0c61d'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'PETRA BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '27',
#   'Block Batch Number': 'LI02172',
#   'Material': '30030172',
#   'Material description': 'PNMS PETRA.BRN_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cdff0f1441818b0c621'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'ROSATIKA',
#   'Storage location': '1130',
#   'Hanger and Angle': '118',
#   'Block Batch Number': 'LG60831',
#   'Material': '30029764',
#   'Material description': 'HNMS ROSATIKA_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3ce3f0f1441818b0c634'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'ROSSO CASATA',
#   'Storage location': '1130',
#   'Hanger and Angle': '45',
#   'Block Batch Number': 'LJ00691',
#   'Material': '30031545',
#   'Material description': 'ONMS RS.CASATA_CS-18MM-IMFG'},
#  {'_id': ObjectId('5fec3ce4f0f1441818b0c63e'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'SAINT LAURENT',
#   'Storage location': '1131',
#   'Hanger and Angle': '70',
#   'Block Batch Number': 'LJ01025',
#   'Material': '30029782',
#   'Material description': 'HNMS SNT.LRNT_TN-18MM-IMFG'},
#  {'_id': ObjectId('5fec3ce7f0f1441818b0c642'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'SAINT LAURENT',
#   'Storage location': '1131',
#   'Hanger and Angle': '87',
#   'Block Batch Number': 'LI01283',
#   'Material': '30029782',
#   'Material description': 'HNMS SNT.LRNT_TN-18MM-IMFG'},
#  {'_id': ObjectId('5fec3ce7f0f1441818b0c644'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'SAINT LAURENT',
#   'Storage location': '1131',
#   'Hanger and Angle': '90',
#   'Block Batch Number': 'LI01281',
#   'Material': '30029782',
#   'Material description': 'HNMS SNT.LRNT_TN-18MM-IMFG'},
#  {'_id': ObjectId('5fec3ce8f0f1441818b0c648'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'SAINT LAURENT',
#   'Storage location': '1131',
#   'Hanger and Angle': '103',
#   'Block Batch Number': 'LI01276',
#   'Material': '30030202',
#   'Material description': 'PNMS SNT.LRNT_TN-18MM-IMFG'},
#  {'_id': ObjectId('5fec3ce9f0f1441818b0c654'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'SAINT LAURENT',
#   'Storage location': '1131',
#   'Hanger and Angle': '87',
#   'Block Batch Number': 'LJ00153',
#   'Material': '30030202',
#   'Material description': 'PNMS SNT.LRNT_TN-18MM-IMFG'},
#  {'_id': ObjectId('5fec3ce9f0f1441818b0c656'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'SAINT LAURENT',
#   'Storage location': '1131',
#   'Hanger and Angle': '81',
#   'Block Batch Number': 'LI00115',
#   'Material': '30030203',
#   'Material description': 'PNMS SNT.LRNT_TN-20MM-IMFG'},
#  {'_id': ObjectId('5fec3ceaf0f1441818b0c65a'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'SILKER BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '36',
#   'Block Batch Number': 'LG60409',
#   'Material': '30033110',
#   'Material description': 'HNMS SLKR.BRN_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cecf0f1441818b0c663'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'TOBACCO BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '35',
#   'Block Batch Number': 'LF61939A',
#   'Material': '30030212',
#   'Material description': 'PNMS TBC.BRN_CA-20MM-IMFG'},
#  {'_id': ObjectId('5fec3cecf0f1441818b0c664'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'TOBACCO BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '35',
#   'Block Batch Number': 'LF61939B',
#   'Material': '30030212',
#   'Material description': 'PNMS TBC.BRN_CA-20MM-IMFG'},
#  {'_id': ObjectId('5fec3cedf0f1441818b0c667'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'VENICE BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '62',
#   'Block Batch Number': '11KJ070',
#   'Material': '40001050',
#   'Material description': 'PNMS VNC.BRN_CN-18MM-IMP'},
#  {'_id': ObjectId('5fec3cd0f0f1441818b0c575'),
#   'Colour': 'BEIGE',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'TERRACOTTA',
#   'Storage location': '1130',
#   'Hanger and Angle': '39',
#   'Block Batch Number': 'LH00659',
#   'Material': '30031425',
#   'Material description': 'HNMS TERRACOTTA_TR-20MM-IMFG'},
#  {'_id': ObjectId('5fec3cd0f0f1441818b0c577'),
#   'Colour': 'BEIGE',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'TERRACOTTA',
#   'Storage location': '1130',
#   'Hanger and Angle': '89',
#   'Block Batch Number': 'LJ00764',
#   'Material': '30031427',
#   'Material description': 'PNMS TERRACOTTA_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cd0f0f1441818b0c579'),
#   'Colour': 'BEIGE',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'TERRACOTTA',
#   'Storage location': '1130',
#   'Hanger and Angle': '36',
#   'Block Batch Number': 'LH00659',
#   'Material': '30031428',
#   'Material description': 'PNMS TERRACOTTA_TR-20MM-IMFG'},
#  {'_id': ObjectId('5fec3cd1f0f1441818b0c592'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BLACK MARQUINA',
#   'Storage location': '1131',
#   'Hanger and Angle': '80',
#   'Block Batch Number': '11KJ250',
#   'Material': '40001072',
#   'Material description': 'PNMS BLK.MRQ_CN-18MM-IMP'},
#  {'_id': ObjectId('5fec3cd4f0f1441818b0c5a0'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'GOLDEN PORTORO',
#   'Storage location': '1131',
#   'Hanger and Angle': '71',
#   'Block Batch Number': 'LE60271',
#   'Material': '30030086',
#   'Material description': 'PNMS GLD.PORTO_DO-20MM-IMFG'},
#  {'_id': ObjectId('5fec3cd4f0f1441818b0c5a3'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'GOLDEN PORTORO',
#   'Storage location': '1131',
#   'Hanger and Angle': '61',
#   'Block Batch Number': '21UF0012',
#   'Material': '40001123',
#   'Material description': 'PNMS GLD.PORTO_CN-18MM-IMP'},
#  {'_id': ObjectId('5fec3cd4f0f1441818b0c5a8'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'GOLDEN PORTORO',
#   'Storage location': '1131',
#   'Hanger and Angle': '74',
#   'Block Batch Number': '11KJ186',
#   'Material': '40001123',
#   'Material description': 'PNMS GLD.PORTO_CN-18MM-IMP'},
#  {'_id': ObjectId('5fec3cd4f0f1441818b0c5a9'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'GOLDEN PORTORO',
#   'Storage location': '1131',
#   'Hanger and Angle': '89',
#   'Block Batch Number': '11KJ100',
#   'Material': '40001123',
#   'Material description': 'PNMS GLD.PORTO_CN-18MM-IMP'},
#  {'_id': ObjectId('5fec3cd4f0f1441818b0c5ad'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'SAINT LAURENT',
#   'Storage location': '1130',
#   'Hanger and Angle': '99',
#   'Block Batch Number': 'LF00353',
#   'Material': '30033131',
#   'Material description': 'HNMS SNT.LRNT_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cd4f0f1441818b0c5ae'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'SAINT LAURENT',
#   'Storage location': '1130',
#   'Hanger and Angle': '99',
#   'Block Batch Number': 'LF00353',
#   'Material': '30033833',
#   'Material description': 'PNMS SNT.LRNT_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cd5f0f1441818b0c5b3'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'SPIDER BLACK',
#   'Storage location': '1130',
#   'Hanger and Angle': '87',
#   'Block Batch Number': 'LJ01920',
#   'Material': '30035951',
#   'Material description': 'PNMS SPD.BLK_AE-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cd5f0f1441818b0c5c1'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'ARMANI BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '10',
#   'Block Batch Number': 'LG62518',
#   'Material': '30029961',
#   'Material description': 'PNMS ARMN.BRN_TR-16MM-IMFG'},
#  {'_id': ObjectId('5fec3cd6f0f1441818b0c5c6'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'ARMANI BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '21',
#   'Block Batch Number': 'LJ01210A',
#   'Material': '30029961',
#   'Material description': 'PNMS ARMN.BRN_TR-16MM-IMFG'},
#  {'_id': ObjectId('5fec3cd6f0f1441818b0c5c7'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'ARMANI BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '24',
#   'Block Batch Number': 'LH00447',
#   'Material': '30029961',
#   'Material description': 'PNMS ARMN.BRN_TR-16MM-IMFG'},
#  {'_id': ObjectId('5fec3cd6f0f1441818b0c5ca'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'ARMANI BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '3',
#   'Block Batch Number': 'LJ01211',
#   'Material': '30029962',
#   'Material description': 'PNMS ARMN.BRN_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cd7f0f1441818b0c5da'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BROWN FANTACY DIANA',
#   'Storage location': '1130',
#   'Hanger and Angle': '61',
#   'Block Batch Number': '11KI136',
#   'Material': '40001345',
#   'Material description': 'PNMS BRN.FNTS.DNA_CN-18MM-IMP'},
#  {'_id': ObjectId('5fec3cd7f0f1441818b0c5e2'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BROWN ONYX',
#   'Storage location': '1130',
#   'Hanger and Angle': '37',
#   'Block Batch Number': 'LE60442',
#   'Material': '30032654',
#   'Material description': 'HNMS BRN.ONYX_PK-20MM-IMFG'},
#  {'_id': ObjectId('5fec3cdaf0f1441818b0c5ed'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'DARK EMPRADOR',
#   'Storage location': '1130',
#   'Hanger and Angle': '71',
#   'Block Batch Number': 'LH61680',
#   'Material': '30030043',
#   'Material description': 'PNMS DARK.EMP_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cdcf0f1441818b0c5fd'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'IRISH BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '94',
#   'Block Batch Number': 'LJ00537',
#   'Material': '30031017',
#   'Material description': 'HNMS IRIS.BRN_CN-16MM-IMFG'},
#  {'_id': ObjectId('5fec3cddf0f1441818b0c60b'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'MONACO BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '119',
#   'Block Batch Number': 'LH61077',
#   'Material': '30030145',
#   'Material description': 'PNMS MNC.BRN_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cdef0f1441818b0c618'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'PEARL ARMANI BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '24',
#   'Block Batch Number': 'LH61061',
#   'Material': '30033734',
#   'Material description': 'PNMS PRL.ARM.BRN_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cdff0f1441818b0c61e'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'ROSATIKA',
#   'Storage location': '1130',
#   'Hanger and Angle': '36',
#   'Block Batch Number': 'LH00223',
#   'Material': '30029763',
#   'Material description': 'HNMS ROSATIKA_TR-16MM-IMFG'},
#  {'_id': ObjectId('5fec3cdff0f1441818b0c622'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'ROSATIKA',
#   'Storage location': '1130',
#   'Hanger and Angle': '36',
#   'Block Batch Number': 'LH00223',
#   'Material': '30030183',
#   'Material description': 'PNMS ROSATIKA_TR-16MM-IMFG'},
#  {'_id': ObjectId('5fec3cdff0f1441818b0c624'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'ROSATIKA',
#   'Storage location': '1131',
#   'Hanger and Angle': '10',
#   'Block Batch Number': 'LH00220',
#   'Material': '30030183',
#   'Material description': 'PNMS ROSATIKA_TR-16MM-IMFG'},
#  {'_id': ObjectId('5fec3cdff0f1441818b0c625'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'ROSATIKA',
#   'Storage location': '1130',
#   'Hanger and Angle': '118',
#   'Block Batch Number': 'LG60831',
#   'Material': '30030184',
#   'Material description': 'PNMS ROSATIKA_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3ce2f0f1441818b0c630'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'ROSSO CASATA',
#   'Storage location': '1130',
#   'Hanger and Angle': '45',
#   'Block Batch Number': 'LJ00691',
#   'Material': '30030783',
#   'Material description': 'PNMS RS.CASATA_CS-18MM-IMFG'},
#  {'_id': ObjectId('5fec3ce3f0f1441818b0c637'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'SAINT LAURENT',
#   'Storage location': '1131',
#   'Hanger and Angle': '59',
#   'Block Batch Number': 'LJ00156',
#   'Material': '30029782',
#   'Material description': 'HNMS SNT.LRNT_TN-18MM-IMFG'},
#  {'_id': ObjectId('5fec3ce4f0f1441818b0c63b'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'SAINT LAURENT',
#   'Storage location': '1131',
#   'Hanger and Angle': '69',
#   'Block Batch Number': 'LI01282',
#   'Material': '30029782',
#   'Material description': 'HNMS SNT.LRNT_TN-18MM-IMFG'},
#  {'_id': ObjectId('5fec3ce8f0f1441818b0c646'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'SAINT LAURENT',
#   'Storage location': '1131',
#   'Hanger and Angle': '88',
#   'Block Batch Number': 'LI00120',
#   'Material': '30029783',
#   'Material description': 'HNMS SNT.LRNT_TN-20MM-IMFG'},
#  {'_id': ObjectId('5fec3ce8f0f1441818b0c647'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'SAINT LAURENT',
#   'Storage location': '1131',
#   'Hanger and Angle': '90',
#   'Block Batch Number': 'LI00115',
#   'Material': '30029783',
#   'Material description': 'HNMS SNT.LRNT_TN-20MM-IMFG'},
#  {'_id': ObjectId('5fec3ceaf0f1441818b0c65b'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'SILKER BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '88',
#   'Block Batch Number': 'LJ01818',
#   'Material': '30033110',
#   'Material description': 'HNMS SLKR.BRN_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cedf0f1441818b0c668'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'VENICE BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '68',
#   'Block Batch Number': '11KJ064',
#   'Material': '40001050',
#   'Material description': 'PNMS VNC.BRN_CN-18MM-IMP'},
#  {'_id': ObjectId('5fec3cc6f0f1441818b0c568'),
#   'Colour': 'BEIGE',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BRECCIA ONICIATA',
#   'Storage location': '1130',
#   'Hanger and Angle': '100',
#   'Block Batch Number': 'LI00547',
#   'Material': '30029509',
#   'Material description': 'HNMS BC.ONC_IT-18MM-IMFG'},
#  {'_id': ObjectId('5fec3ccaf0f1441818b0c56a'),
#   'Colour': 'BEIGE',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BRECCIA ONICIATA',
#   'Storage location': '1130',
#   'Hanger and Angle': '100',
#   'Block Batch Number': 'LI00547',
#   'Material': '30029929',
#   'Material description': 'PNMS BC.ONC_IT-18MM-IMFG'},
#  {'_id': ObjectId('5fec3ccaf0f1441818b0c56b'),
#   'Colour': 'BEIGE',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BRECCIA ONICIATA',
#   'Storage location': '1130',
#   'Hanger and Angle': '27',
#   'Block Batch Number': 'LI02577',
#   'Material': '30029929',
#   'Material description': 'PNMS BC.ONC_IT-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cd1f0f1441818b0c58f'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BLACK MARQUINA',
#   'Storage location': '1131',
#   'Hanger and Angle': '65',
#   'Block Batch Number': '11KJ246',
#   'Material': '40001072',
#   'Material description': 'PNMS BLK.MRQ_CN-18MM-IMP'},
#  {'_id': ObjectId('5fec3cd1f0f1441818b0c594'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BLACK MARQUINA',
#   'Storage location': '1131',
#   'Hanger and Angle': '71',
#   'Block Batch Number': '11KJ218',
#   'Material': '40001226',
#   'Material description': 'PNMS BLK.MRQ_CN-20MM-IMP'},
#  {'_id': ObjectId('5fec3cd1f0f1441818b0c598'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BLACK WAVE',
#   'Storage location': '1131',
#   'Hanger and Angle': '62',
#   'Block Batch Number': 'LI01366',
#   'Material': '30029608',
#   'Material description': 'HNMS BLK.WAVE_CN-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cd1f0f1441818b0c59a'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'CELSIUM BLACK',
#   'Storage location': '1130',
#   'Hanger and Angle': '57',
#   'Block Batch Number': 'K00CB92',
#   'Material': '40001373',
#   'Material description': 'PNMS CLSM.BLK_CN-20MM-IMP'},
#  {'_id': ObjectId('5fec3cd3f0f1441818b0c59d'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'CLASSIC PICASO',
#   'Storage location': '1131',
#   'Hanger and Angle': '106',
#   'Block Batch Number': 'LG61001',
#   'Material': '30034113',
#   'Material description': 'ONMS CLS.PICASO_TR-20MM-IMFG'},
#  {'_id': ObjectId('5fec3cd4f0f1441818b0c5a1'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'GOLDEN PORTORO',
#   'Storage location': '1131',
#   'Hanger and Angle': '72',
#   'Block Batch Number': 'LE60272',
#   'Material': '30030086',
#   'Material description': 'PNMS GLD.PORTO_DO-20MM-IMFG'},
#  {'_id': ObjectId('5fec3cd4f0f1441818b0c5aa'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'GOLDEN PORTORO',
#   'Storage location': '1131',
#   'Hanger and Angle': '61',
#   'Block Batch Number': '21KG0178',
#   'Material': '40001183',
#   'Material description': 'PNMS GLD.PORTO_CN-20MM-IMP'},
#  {'_id': ObjectId('5fec3cd4f0f1441818b0c5b0'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'SPIDER BLACK',
#   'Storage location': '1130',
#   'Hanger and Angle': '87',
#   'Block Batch Number': 'LJ01920',
#   'Material': '30035936',
#   'Material description': 'HNMS SPD.BLK_AE-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cd4f0f1441818b0c5b2'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'SPIDER BLACK',
#   'Storage location': '1130',
#   'Hanger and Angle': '90',
#   'Block Batch Number': 'LJ01919',
#   'Material': '30035936',
#   'Material description': 'HNMS SPD.BLK_AE-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cd5f0f1441818b0c5b7'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'AMARONE BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '2',
#   'Block Batch Number': 'LI02587',
#   'Material': '30029914',
#   'Material description': 'HNMS AMRON.BRN_AE-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cd5f0f1441818b0c5b9'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'ARMANI BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '10',
#   'Block Batch Number': 'LG62518',
#   'Material': '30029541',
#   'Material description': 'HNMS ARMN.BRN_TR-16MM-IMFG'},
#  {'_id': ObjectId('5fec3cd6f0f1441818b0c5ce'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BEIGE BENZ BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '81',
#   'Block Batch Number': 'LJ00594',
#   'Material': '30031171',
#   'Material description': 'PNMS BGE.BNZ.BRN_AL-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cd6f0f1441818b0c5d4'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BRECCIA BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '80',
#   'Block Batch Number': 'LJ01936',
#   'Material': '30030615',
#   'Material description': 'HNMS BRC.BRN_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cd6f0f1441818b0c5d8'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BRECCIA BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '80',
#   'Block Batch Number': 'LJ01936',
#   'Material': '30030672',
#   'Material description': 'PNMS BRC.BRN_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cdaf0f1441818b0c5eb'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'DARK EMPRADOR',
#   'Storage location': '1130',
#   'Hanger and Angle': '74',
#   'Block Batch Number': 'LH61686',
#   'Material': '30029623',
#   'Material description': 'HNMS DARK.EMP_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cdaf0f1441818b0c5f2'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'EMPERADOR',
#   'Storage location': '1130',
#   'Hanger and Angle': '66',
#   'Block Batch Number': 'LJ01111',
#   'Material': '30034816',
#   'Material description': 'PNMS EMPERADOR_TR-16MM-IMFG'},
#  {'_id': ObjectId('5fec3cdbf0f1441818b0c5f3'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'EMPERADOR',
#   'Storage location': '1130',
#   'Hanger and Angle': '70',
#   'Block Batch Number': 'LJ01110',
#   'Material': '30034816',
#   'Material description': 'PNMS EMPERADOR_TR-16MM-IMFG'},
#  {'_id': ObjectId('5fec3cdbf0f1441818b0c5f6'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'FANTASY BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '104',
#   'Block Batch Number': 'LJ00214',
#   'Material': '30030633',
#   'Material description': 'HNMS FNTSY.BRN_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cdcf0f1441818b0c5fc'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'IRISH BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '84',
#   'Block Batch Number': 'LJ00686',
#   'Material': '30031017',
#   'Material description': 'HNMS IRIS.BRN_CN-16MM-IMFG'},
#  {'_id': ObjectId('5fec3cdcf0f1441818b0c601'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'IRISH BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '94',
#   'Block Batch Number': 'LJ00537',
#   'Material': '30031018',
#   'Material description': 'PNMS IRIS.BRN_CN-16MM-IMFG'},
#  {'_id': ObjectId('5fec3cdcf0f1441818b0c604'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'IRISH BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '59',
#   'Block Batch Number': '21KH0265',
#   'Material': '40001128',
#   'Material description': 'PNMS IRIS.BRN_CN-16MM-IMP'},
#  {'_id': ObjectId('5fec3cddf0f1441818b0c60a'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'MONACO BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '117',
#   'Block Batch Number': 'LI01965',
#   'Material': '30030145',
#   'Material description': 'PNMS MNC.BRN_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cddf0f1441818b0c611'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'OCEAN BROWN',
#   'Storage location': '1131',
#   'Hanger and Angle': '17',
#   'Block Batch Number': 'LJ00064',
#   'Material': '30030642',
#   'Material description': 'PNMS OCN.BRN_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cdef0f1441818b0c617'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'PEARL ARMANI BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '128',
#   'Block Batch Number': 'LH61531',
#   'Material': '30033734',
#   'Material description': 'PNMS PRL.ARM.BRN_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cdff0f1441818b0c61f'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'ROSATIKA',
#   'Storage location': '1130',
#   'Hanger and Angle': '40',
#   'Block Batch Number': 'LH00221',
#   'Material': '30029763',
#   'Material description': 'HNMS ROSATIKA_TR-16MM-IMFG'},
#  {'_id': ObjectId('5fec3ce4f0f1441818b0c63c'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'SAINT LAURENT',
#   'Storage location': '1131',
#   'Hanger and Angle': '69',
#   'Block Batch Number': 'LI01289',
#   'Material': '30029782',
#   'Material description': 'HNMS SNT.LRNT_TN-18MM-IMFG'},
#  {'_id': ObjectId('5fec3ce8f0f1441818b0c64f'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'SAINT LAURENT',
#   'Storage location': '1131',
#   'Hanger and Angle': '70',
#   'Block Batch Number': 'LJ01025',
#   'Material': '30030202',
#   'Material description': 'PNMS SNT.LRNT_TN-18MM-IMFG'},
#  {'_id': ObjectId('5fec3ce8f0f1441818b0c650'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'SAINT LAURENT',
#   'Storage location': '1131',
#   'Hanger and Angle': '76',
#   'Block Batch Number': 'LJ00152',
#   'Material': '30030202',
#   'Material description': 'PNMS SNT.LRNT_TN-18MM-IMFG'},
#  {'_id': ObjectId('5fec3ce9f0f1441818b0c651'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'SAINT LAURENT',
#   'Storage location': '1131',
#   'Hanger and Angle': '77',
#   'Block Batch Number': 'LI01290',
#   'Material': '30030202',
#   'Material description': 'PNMS SNT.LRNT_TN-18MM-IMFG'},
#  {'_id': ObjectId('5fec3ce9f0f1441818b0c653'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'SAINT LAURENT',
#   'Storage location': '1131',
#   'Hanger and Angle': '87',
#   'Block Batch Number': 'LI01283',
#   'Material': '30030202',
#   'Material description': 'PNMS SNT.LRNT_TN-18MM-IMFG'},
#  {'_id': ObjectId('5fec3ccbf0f1441818b0c571'),
#   'Colour': 'BEIGE',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'TERRACOTTA',
#   'Storage location': '1130',
#   'Hanger and Angle': '83',
#   'Block Batch Number': 'LJ00763',
#   'Material': '30031424',
#   'Material description': 'HNMS TERRACOTTA_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3ccbf0f1441818b0c572'),
#   'Colour': 'BEIGE',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'TERRACOTTA',
#   'Storage location': '1130',
#   'Hanger and Angle': '89',
#   'Block Batch Number': 'LJ00764',
#   'Material': '30031424',
#   'Material description': 'HNMS TERRACOTTA_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cd0f0f1441818b0c576'),
#   'Colour': 'BEIGE',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'TERRACOTTA',
#   'Storage location': '1130',
#   'Hanger and Angle': '83',
#   'Block Batch Number': 'LJ00763',
#   'Material': '30031427',
#   'Material description': 'PNMS TERRACOTTA_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cd0f0f1441818b0c583'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BLACK MARQUINA',
#   'Storage location': '1131',
#   'Hanger and Angle': '58',
#   'Block Batch Number': 'LH61611',
#   'Material': '30029997',
#   'Material description': 'PNMS BLK.MRQ_MA-16MM-IMFG'},
#  {'_id': ObjectId('5fec3cd0f0f1441818b0c588'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BLACK MARQUINA',
#   'Storage location': '1131',
#   'Hanger and Angle': '45',
#   'Block Batch Number': '11KJ123',
#   'Material': '40001072',
#   'Material description': 'PNMS BLK.MRQ_CN-18MM-IMP'},
#  {'_id': ObjectId('5fec3cd1f0f1441818b0c58a'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BLACK MARQUINA',
#   'Storage location': '1131',
#   'Hanger and Angle': '56',
#   'Block Batch Number': '11KJ123',
#   'Material': '40001072',
#   'Material description': 'PNMS BLK.MRQ_CN-18MM-IMP'},
#  {'_id': ObjectId('5fec3cd1f0f1441818b0c593'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BLACK MARQUINA',
#   'Storage location': '1131',
#   'Hanger and Angle': '61',
#   'Block Batch Number': '21KG0049',
#   'Material': '40001226',
#   'Material description': 'PNMS BLK.MRQ_CN-20MM-IMP'},
#  {'_id': ObjectId('5fec3cd4f0f1441818b0c5a6'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'GOLDEN PORTORO',
#   'Storage location': '1131',
#   'Hanger and Angle': '67',
#   'Block Batch Number': '11KJ244',
#   'Material': '40001123',
#   'Material description': 'PNMS GLD.PORTO_CN-18MM-IMP'},
#  {'_id': ObjectId('5fec3cd4f0f1441818b0c5a7'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'GOLDEN PORTORO',
#   'Storage location': '1131',
#   'Hanger and Angle': '73',
#   'Block Batch Number': '11KJ127',
#   'Material': '40001123',
#   'Material description': 'PNMS GLD.PORTO_CN-18MM-IMP'},
#  {'_id': ObjectId('5fec3cd4f0f1441818b0c5ac'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'GOLDEN PORTORO',
#   'Storage location': '1131',
#   'Hanger and Angle': '67',
#   'Block Batch Number': '11KJ244',
#   'Material': '40001772',
#   'Material description': 'RNMS GLD.PORTO_CN-18MM-IMP'},
#  {'_id': ObjectId('5fec3cd5f0f1441818b0c5b4'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'SPIDER BLACK',
#   'Storage location': '1130',
#   'Hanger and Angle': '87',
#   'Block Batch Number': 'LJ01922',
#   'Material': '30035951',
#   'Material description': 'PNMS SPD.BLK_AE-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cd6f0f1441818b0c5c5'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'ARMANI BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '11',
#   'Block Batch Number': 'LJ01212',
#   'Material': '30029961',
#   'Material description': 'PNMS ARMN.BRN_TR-16MM-IMFG'},
#  {'_id': ObjectId('5fec3cd6f0f1441818b0c5d3'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BRECCIA BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '79',
#   'Block Batch Number': 'LJ01934',
#   'Material': '30030615',
#   'Material description': 'HNMS BRC.BRN_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cd6f0f1441818b0c5d7'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BRECCIA BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '79',
#   'Block Batch Number': 'LJ01934',
#   'Material': '30030672',
#   'Material description': 'PNMS BRC.BRN_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cd7f0f1441818b0c5dd'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BROWN LAZULY',
#   'Storage location': '1130',
#   'Hanger and Angle': '76',
#   'Block Batch Number': 'LE01339',
#   'Material': '30029596',
#   'Material description': 'HNMS BRN.LZLY_IT-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cd7f0f1441818b0c5e0'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BROWN ONYX',
#   'Storage location': '1130',
#   'Hanger and Angle': '37',
#   'Block Batch Number': 'LE60441A',
#   'Material': '30032654',
#   'Material description': 'HNMS BRN.ONYX_PK-20MM-IMFG'},
#  {'_id': ObjectId('5fec3cd9f0f1441818b0c5e5'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BROWN ONYX',
#   'Storage location': '1130',
#   'Hanger and Angle': '37',
#   'Block Batch Number': 'LE60442',
#   'Material': '30033357',
#   'Material description': 'PNMS BRN.ONYX_PK-20MM-IMFG'},
#  {'_id': ObjectId('5fec3cdaf0f1441818b0c5e8'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BROWN PERLA',
#   'Storage location': '1130',
#   'Hanger and Angle': '43',
#   'Block Batch Number': 'LJ00066',
#   'Material': '30030660',
#   'Material description': 'PNMS BRN.PERLA_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cdaf0f1441818b0c5e9'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BROWN PERLA',
#   'Storage location': '1131',
#   'Hanger and Angle': '59',
#   'Block Batch Number': 'LG60756',
#   'Material': '30030660',
#   'Material description': 'PNMS BRN.PERLA_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cdaf0f1441818b0c5ea'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'DARK EMPRADOR',
#   'Storage location': '1130',
#   'Hanger and Angle': '70',
#   'Block Batch Number': 'LG60999',
#   'Material': '30029623',
#   'Material description': 'HNMS DARK.EMP_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cdaf0f1441818b0c5f1'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'EMPERADOR',
#   'Storage location': '1130',
#   'Hanger and Angle': '70',
#   'Block Batch Number': 'LJ01110',
#   'Material': '30034813',
#   'Material description': 'HNMS EMPERADOR_TR-16MM-IMFG'},
#  {'_id': ObjectId('5fec3cdcf0f1441818b0c5fe'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'IRISH BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '109',
#   'Block Batch Number': 'LJ00653',
#   'Material': '30031018',
#   'Material description': 'PNMS IRIS.BRN_CN-16MM-IMFG'},
#  {'_id': ObjectId('5fec3cdcf0f1441818b0c606'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'MONACO BROWN',
# ...
#   'Mara-Quality Name': 'OCEAN BROWN',
#   'Storage location': '1131',
#   'Hanger and Angle': '17',
#   'Block Batch Number': 'LJ00064',
#   'Material': '30030585',
#   'Material description': 'HNMS OCN.BRN_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cdef0f1441818b0c614'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'PEARL ARMANI BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '128',
#   'Block Batch Number': 'LH61531',
#   'Material': '30033032',
#   'Material description': 'HNMS PRL.ARM.BRN_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cdef0f1441818b0c61c'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'PETRA BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '115',
#   'Block Batch Number': 'LI02173',
#   'Material': '30030172',
#   'Material description': 'PNMS PETRA.BRN_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3ce2f0f1441818b0c631'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'ROSSO CASATA',
#   'Storage location': '1130',
#   'Hanger and Angle': '45',
#   'Block Batch Number': 'LJ00698',
#   'Material': '30030783',
#   'Material description': 'PNMS RS.CASATA_CS-18MM-IMFG'},
#  {'_id': ObjectId('5fec3ce2f0f1441818b0c633'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'ROSSO CASATA',
#   'Storage location': '1130',
#   'Hanger and Angle': '78',
#   'Block Batch Number': 'LJ00324',
#   'Material': '30030783',
#   'Material description': 'PNMS RS.CASATA_CS-18MM-IMFG'},
#  {'_id': ObjectId('5fec3ce3f0f1441818b0c636'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'SAINT LAURENT',
#   'Storage location': '1131',
#   'Hanger and Angle': '49',
#   'Block Batch Number': 'LJ00157',
#   'Material': '30029782',
#   'Material description': 'HNMS SNT.LRNT_TN-18MM-IMFG'},
#  {'_id': ObjectId('5fec3ce4f0f1441818b0c63f'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'SAINT LAURENT',
#   'Storage location': '1131',
#   'Hanger and Angle': '76',
#   'Block Batch Number': 'LJ00152',
#   'Material': '30029782',
#   'Material description': 'HNMS SNT.LRNT_TN-18MM-IMFG'},
#  {'_id': ObjectId('5fec3ce7f0f1441818b0c641'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'SAINT LAURENT',
#   'Storage location': '1131',
#   'Hanger and Angle': '78',
#   'Block Batch Number': 'LI01292',
#   'Material': '30029782',
#   'Material description': 'HNMS SNT.LRNT_TN-18MM-IMFG'},
#  {'_id': ObjectId('5fec3ce8f0f1441818b0c649'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'SAINT LAURENT',
#   'Storage location': '1131',
#   'Hanger and Angle': '49',
#   'Block Batch Number': 'LJ00157',
#   'Material': '30030202',
#   'Material description': 'PNMS SNT.LRNT_TN-18MM-IMFG'},
#  {'_id': ObjectId('5fec3ce9f0f1441818b0c658'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'SAINT LAURENT',
#   'Storage location': '1131',
#   'Hanger and Angle': '90',
#   'Block Batch Number': 'LI00115',
#   'Material': '30030203',
#   'Material description': 'PNMS SNT.LRNT_TN-20MM-IMFG'},
#  {'_id': ObjectId('5fec3ceaf0f1441818b0c65c'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'SILKER BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '121',
#   'Block Batch Number': 'LG60402',
#   'Material': '30033812',
#   'Material description': 'PNMS SLKR.BRN_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cebf0f1441818b0c65e'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'SILKER BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '36',
#   'Block Batch Number': 'LG60409',
#   'Material': '30033812',
#   'Material description': 'PNMS SLKR.BRN_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cecf0f1441818b0c661'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'TOBACCO BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '35',
#   'Block Batch Number': 'LF61939B',
#   'Material': '30029792',
#   'Material description': 'HNMS TBC.BRN_CA-20MM-IMFG'},
#  {'_id': ObjectId('5fec3ccbf0f1441818b0c56f'),
#   'Colour': 'BEIGE',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'RTM BEIGE',
#   'Storage location': '1130',
#   'Hanger and Angle': '121',
#   'Block Batch Number': 'LJ00784',
#   'Material': '30031489',
#   'Material description': 'PNMS RTM.BGE_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cd0f0f1441818b0c57b'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BLACK ARMANI',
#   'Storage location': '1131',
#   'Hanger and Angle': '87',
#   'Block Batch Number': 'LI00937',
#   'Material': '30029567',
#   'Material description': 'HNMS BLK.ARMN_IR-20MM-IMFG'},
#  {'_id': ObjectId('5fec3cd0f0f1441818b0c57d'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BLACK ARMANI',
#   'Storage location': '1131',
#   'Hanger and Angle': '87',
#   'Block Batch Number': 'LI00937',
#   'Material': '30029987',
#   'Material description': 'PNMS BLK.ARMN_IR-20MM-IMFG'},
#  {'_id': ObjectId('5fec3cd0f0f1441818b0c580'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BLACK MARQUINA',
#   'Storage location': '1130',
#   'Hanger and Angle': '63',
#   'Block Batch Number': 'LG61270',
#   'Material': '30029578',
#   'Material description': 'HNMS BLK.MRQ_MA-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cd0f0f1441818b0c581'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BLACK MARQUINA',
#   'Storage location': '1131',
#   'Hanger and Angle': '63',
#   'Block Batch Number': 'LH61607',
#   'Material': '30029578',
#   'Material description': 'HNMS BLK.MRQ_MA-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cd0f0f1441818b0c584'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BLACK MARQUINA',
#   'Storage location': '1131',
#   'Hanger and Angle': '58',
#   'Block Batch Number': 'LI02516',
#   'Material': '30029997',
#   'Material description': 'PNMS BLK.MRQ_MA-16MM-IMFG'},
#  {'_id': ObjectId('5fec3cd0f0f1441818b0c589'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BLACK MARQUINA',
#   'Storage location': '1131',
#   'Hanger and Angle': '49',
#   'Block Batch Number': '11KJ226',
#   'Material': '40001072',
#   'Material description': 'PNMS BLK.MRQ_CN-18MM-IMP'},
#  {'_id': ObjectId('5fec3cd1f0f1441818b0c58c'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BLACK MARQUINA',
#   'Storage location': '1131',
#   'Hanger and Angle': '61',
#   'Block Batch Number': '11KI005',
#   'Material': '40001072',
#   'Material description': 'PNMS BLK.MRQ_CN-18MM-IMP'},
#  {'_id': ObjectId('5fec3cd1f0f1441818b0c597'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BLACK MARQUINA',
#   'Storage location': '1131',
#   'Hanger and Angle': '67',
#   'Block Batch Number': '11KJ215',
#   'Material': '40001748',
#   'Material description': 'PNMS BLK.MRQ_IN-20MM-IND'},
#  {'_id': ObjectId('5fec3cd1f0f1441818b0c599'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'CELSIUM BLACK',
#   'Storage location': '1130',
#   'Hanger and Angle': '57',
#   'Block Batch Number': 'K00CB50',
#   'Material': '40001373',
#   'Material description': 'PNMS CLSM.BLK_CN-20MM-IMP'},
#  {'_id': ObjectId('5fec3cd1f0f1441818b0c59c'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'CLASSIC PICASO',
#   'Storage location': '1131',
#   'Hanger and Angle': '106',
#   'Block Batch Number': 'LG61001',
#   'Material': '30033411',
#   'Material description': 'PNMS CLS.PICASO_TR-20MM-IMFG'},
#  {'_id': ObjectId('5fec3cd4f0f1441818b0c5a5'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'GOLDEN PORTORO',
#   'Storage location': '1131',
#   'Hanger and Angle': '61',
#   'Block Batch Number': '21UF0072',
#   'Material': '40001123',
#   'Material description': 'PNMS GLD.PORTO_CN-18MM-IMP'},
#  {'_id': ObjectId('5fec3cd4f0f1441818b0c5af'),
#   'Colour': 'BLACK',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'SAINT LAURENT',
#   'Storage location': '1131',
#   'Hanger and Angle': '88',
#   'Block Batch Number': 'LD00542',
#   'Material': '30033834',
#   'Material description': 'PNMS SNT.LRNT_TR-20MM-IMFG'},
#  {'_id': ObjectId('5fec3cd5f0f1441818b0c5bc'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'ARMANI BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '11',
#   'Block Batch Number': 'LJ01212',
#   'Material': '30029541',
#   'Material description': 'HNMS ARMN.BRN_TR-16MM-IMFG'},
#  {'_id': ObjectId('5fec3cd6f0f1441818b0c5c9'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'ARMANI BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '6',
#   'Block Batch Number': 'LJ00614',
#   'Material': '30029961',
#   'Material description': 'PNMS ARMN.BRN_TR-16MM-IMFG'},
#  {'_id': ObjectId('5fec3cd6f0f1441818b0c5cb'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BEIGE BENZ BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '81',
#   'Block Batch Number': 'LJ00594',
#   'Material': '30031168',
#   'Material description': 'HNMS BGE.BNZ.BRN_AL-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cd6f0f1441818b0c5d0'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BIJOU.BRN',
#   'Storage location': '1131',
#   'Hanger and Angle': '107',
#   'Block Batch Number': 'LJ01067',
#   'Material': '30035059',
#   'Material description': 'PNMS BIJOU.BRN_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cd7f0f1441818b0c5dc'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BROWN LAZULY',
#   'Storage location': '1130',
#   'Hanger and Angle': '69',
#   'Block Batch Number': 'LF62236',
#   'Material': '30029596',
#   'Material description': 'HNMS BRN.LZLY_IT-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cdbf0f1441818b0c5f4'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'EMPRADAR LIGHT',
#   'Storage location': '1130',
#   'Hanger and Angle': '71',
#   'Block Batch Number': 'LI00276',
#   'Material': '30029857',
#   'Material description': 'HNMS EMP.LT_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cdcf0f1441818b0c5fa'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'IRISH BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '112',
#   'Block Batch Number': 'LJ00655',
#   'Material': '30031017',
#   'Material description': 'HNMS IRIS.BRN_CN-16MM-IMFG'},
#  {'_id': ObjectId('5fec3cddf0f1441818b0c60d'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'MONACO BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '126',
#   'Block Batch Number': 'LH61652',
#   'Material': '30030145',
#   'Material description': 'PNMS MNC.BRN_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cddf0f1441818b0c613'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'PEARL ARMANI BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '125',
#   'Block Batch Number': 'LH61068',
#   'Material': '30033032',
#   'Material description': 'HNMS PRL.ARM.BRN_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cdef0f1441818b0c61b'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'PETRA BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '27',
#   'Block Batch Number': 'LI02172',
#   'Material': '30029752',
#   'Material description': 'HNMS PETRA.BRN_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cdff0f1441818b0c623'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'ROSATIKA',
#   'Storage location': '1130',
#   'Hanger and Angle': '40',
#   'Block Batch Number': 'LH00221',
#   'Material': '30030183',
#   'Material description': 'PNMS ROSATIKA_TR-16MM-IMFG'},
#  {'_id': ObjectId('5fec3ce0f0f1441818b0c628'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'ROSSO CASATA',
#   'Storage location': '1130',
#   'Hanger and Angle': '44',
#   'Block Batch Number': 'LJ00693',
#   'Material': '30030780',
#   'Material description': 'HNMS RS.CASATA_CS-18MM-IMFG'},
#  {'_id': ObjectId('5fec3ce1f0f1441818b0c62d'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'ROSSO CASATA',
#   'Storage location': '1130',
#   'Hanger and Angle': '38',
#   'Block Batch Number': 'LJ00691',
#   'Material': '30030783',
#   'Material description': 'PNMS RS.CASATA_CS-18MM-IMFG'},
#  {'_id': ObjectId('5fec3ce2f0f1441818b0c632'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'ROSSO CASATA',
#   'Storage location': '1130',
#   'Hanger and Angle': '49',
#   'Block Batch Number': 'LJ00689',
#   'Material': '30030783',
#   'Material description': 'PNMS RS.CASATA_CS-18MM-IMFG'},
#  {'_id': ObjectId('5fec3ce3f0f1441818b0c639'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'SAINT LAURENT',
#   'Storage location': '1131',
#   'Hanger and Angle': '65',
#   'Block Batch Number': 'LJ01027',
#   'Material': '30029782',
#   'Material description': 'HNMS SNT.LRNT_TN-18MM-IMFG'},
#  {'_id': ObjectId('5fec3ce7f0f1441818b0c645'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'SAINT LAURENT',
#   'Storage location': '1131',
#   'Hanger and Angle': '81',
#   'Block Batch Number': 'LI00115',
#   'Material': '30029783',
#   'Material description': 'HNMS SNT.LRNT_TN-20MM-IMFG'},
#  {'_id': ObjectId('5fec3ce9f0f1441818b0c652'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'SAINT LAURENT',
#   'Storage location': '1131',
#   'Hanger and Angle': '78',
#   'Block Batch Number': 'LI01292',
#   'Material': '30030202',
#   'Material description': 'PNMS SNT.LRNT_TN-18MM-IMFG'},
#  {'_id': ObjectId('5fec3ce9f0f1441818b0c655'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'SAINT LAURENT',
#   'Storage location': '1131',
#   'Hanger and Angle': '90',
#   'Block Batch Number': 'LI01281',
#   'Material': '30030202',
#   'Material description': 'PNMS SNT.LRNT_TN-18MM-IMFG'},
#  {'_id': ObjectId('5fec3ce9f0f1441818b0c657'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'SAINT LAURENT',
#   'Storage location': '1131',
#   'Hanger and Angle': '88',
#   'Block Batch Number': 'LI00120',
#   'Material': '30030203',
#   'Material description': 'PNMS SNT.LRNT_TN-20MM-IMFG'},
#  {'_id': ObjectId('5fec3ceaf0f1441818b0c65d'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'SILKER BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '21',
#   'Block Batch Number': 'LJ01819',
#   'Material': '30033812',
#   'Material description': 'PNMS SLKR.BRN_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cebf0f1441818b0c65f'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'SILKER BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '88',
#   'Block Batch Number': 'LJ01818',
#   'Material': '30033812',
#   'Material description': 'PNMS SLKR.BRN_TR-18MM-IMFG'},
#  {'_id': ObjectId('5fec3cecf0f1441818b0c662'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'TOBACCO BROWN',
#   'Storage location': '1130',
#   'Hanger and Angle': '58',
#   'Block Batch Number': 'LF62916A',
#   'Material': '30029792',
#   'Material description': 'HNMS TBC.BRN_CA-20MM-IMFG'},
#  {'_id': ObjectId('5fec3cedf0f1441818b0c666'),
#   'Colour': 'BROWN',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'TOBACCO BROWN CROSS CUT',
#   'Storage location': '1130',
#   'Hanger and Angle': '57',
#   'Block Batch Number': 'K00TB23',
#   'Material': '40001605',
#   'Material description': 'PNMS TBC.BRNCRC_IT-20MM-IMP'}]
